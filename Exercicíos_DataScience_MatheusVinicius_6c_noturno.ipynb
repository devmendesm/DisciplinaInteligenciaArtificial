# %% [markdown]
# <a href="https://colab.research.google.com/github/devmendesm/DisciplinaInteligenciaArtificial/blob/main/Exercic%C3%ADos_DataScience_MatheusVinicius_6c_noturno.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# 1. Crie um array unidimensional de 50 elementos contendo numeros inteiros aleatorios entre 10 e 100.
# importa a lib numpy e da o apelido np
import numpy as np

# o pacote random faz parte da numpy, sorteia um numero entre 10 e 100, com a quantidade de 50 numeros
array = np.random.randint(10, 101, 50)

# resultado é uma sequencia de valores com 50 elementos
print(array)
# Out:
# [ 15  91  37  11  32  17  30  46  63  38  39  97  92  61  64  99  48  21
#   31  69  99  82  24  17  19 100  97  21  66  16  23  50  97  92  30  86
#   28  99 100  63  20  70  36  22  48  24  92  53  12  64]
# 50
